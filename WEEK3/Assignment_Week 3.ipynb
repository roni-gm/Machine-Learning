# %% [markdown]
# # Feature Engineering
# ### **Mohon membaca setiap instruksi dan tag komentar dengan saksama sebelum melanjutkan pengerjaan.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# Scalling untuk MinMax Scaller
from sklearn.preprocessing import MinMaxScaler
# Set the maximum number of columns and rows to display to a large number
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # B. Outlier Handling

# %% [markdown]
# ### Outlier Handling : InterQuartile Handling

# %%
# untuk plot Q-Q
import scipy.stats as stats

# %%
df_california = pd.read_csv('california_dataset.csv')

# %%
from sklearn.model_selection import train_test_split
# splitting terlebih dahulu


#NOTES :
#train : test = 80:20 atau 75:25 atau (minimum :70:30 atau maksimum: 90:10) bagi angka yg lain (85:15)
#data train di-handling outliernya
#tapi tidak untuk data test, karena data test ibarat representasi data masa depan yang digunakan untuk melihat performa Machine Learning

# %% [markdown]
# ### Assignment 1.a :
# 1. lakukan looping untuk melihat plot distribusi data dan outlier pada kolom-kolom : ['MedInc', 'HouseAge', 'AveRooms','AveBedrms', 'AveOccup'] di california_dataset.csv
# 2. Daftar nama kolom yang Anda cek, kolom_kolom = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']

# %%
# Daftar nama kolom yang ingin dicek
kolom_kolom = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']

# Looping untuk menampilkan distribusi dan outlier
for kolom in kolom_kolom:
    
    plt.figure(figsize=(10,4))
    
    # Plot distribusi data
    plt.subplot(1,2,1)
    sns.histplot(df_california[kolom], kde=True)
    plt.title('Distribusi ' + kolom)
    
    # Plot untuk melihat outlier
    plt.subplot(1,2,2)
    sns.boxplot(x=df_california[kolom])
    plt.title('Outlier ' + kolom)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Assignment 1.b
# 1. Lakukan handling outlier pilih 1 kolom saja yang di handling dengan IQR setelah mengecek distribusinya
# 2. Dan cek distribusinya kembali

# %%
### Assignment 1.b Lakukan handling outlier pilih 1 kolom saja yang di handling dengan IQR setelah mengecek distribusinya
### Dan cek distribusinya kembali


# Membaca dataset
df_california = pd.read_csv('california_dataset.csv')

# Pilih kolom yang ingin di-handle
kolom = 'AveRooms'

# Menghitung Q1 dan Q3
Q1 = df_california[kolom].quantile(0.25)
Q3 = df_california[kolom].quantile(0.75)

# Menghitung IQR
IQR = Q3 - Q1

# Menentukan batas bawah dan atas
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Menghapus outlier
data_clean = df_california[(df_california[kolom] >= lower_bound) & (df_california[kolom] <= upper_bound)]

# Plot distribusi setelah handling outlier
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
sns.histplot(data_clean[kolom], kde=True)
plt.title('Distribusi Setelah Handling Outlier')

plt.subplot(1,2,2)
sns.boxplot(x=data_clean[kolom])
plt.title('Boxplot Setelah Handling Outlier')

plt.tight_layout()
plt.show()

# %%
# Melakukan loop untuk mengecek distribusi tiap kolom


# Membaca dataset
df_california = pd.read_csv('california_dataset.csv')

# Daftar kolom yang ingin dicek
kolom_kolom = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']

# Loop untuk melihat distribusi tiap kolom
for kolom in kolom_kolom:
    plt.figure(figsize=(6,4))
    sns.histplot(df_california[kolom], kde=True)
    plt.title('Distribusi ' + kolom)
    plt.show()

# %% [markdown]
# # C. Missing Value Handling
# Missing Value Merupakan nilai yang hilang di suatu kolom, namun tidak hanya sebatas itu. Untuk nilai yang tidak sesuai tapi muncul didalam suatu kolom tertentu juga bisa dianggap sebagai missing value. Misal tipenya kategorikal tapi isinya ada yang berupa angka dan juga sebaliknya.

# %%
df_company = pd.read_csv('company.csv')

# %% [markdown]
# ### Aturan missing value handling :
# 1. jika tipe datanya itu **numerik** -> handling menggunakan **median** (robust / tahan terhadap outlier)
# 2. jika tipe datanya itu **kategorik / object / string** -> handling menggunakan **mode / modus**

# %%
from sklearn.model_selection import train_test_split
#Splitting terlebih dahulu

#train : test = 80:20 atau 75:25 atau (minimum :70:30 atau maksimum: 90:10) bagi angka yg lain (85:15)

# %% [markdown]
# ## Assignment 2. Missing Value Handling :
# 1. Cek persentase missing value pada kolom Headquarters di company.csv, Cek jenis missing valuenya ?
# 2. apakah di drop atau tidak (gunakan syarat drop kolom jika > 20%)
# 3. jika tidak maka handling, dan dengan cara apa handling nilainya, median atau modus ?

# %%
#Tulis jawaban missing value handling kolom Headquarters disini
train, test = train_test_split(df_company, test_size=0.2, random_state=42)

missing_value_count = train['Headquarters'].isnull().sum()
total_data = len(train)

presentase_missing_value = (missing_value_count / total_data) * 100

print("Jumlah missing value:", missing_value_count)
print("Presentase missing value:", presentase_missing_value, "%")

print("Jenis Missing Value :")
print(train['Headquarters'].isnull())

if presentase_missing_value > 20:
    print("Kolom Headquarters di-drop karena missing value > 20%")
    train = train.drop(columns=['Headquarters'])
else:
    print("Kolom tidak di-drop karena missing value <= 20%")

    modus = train['Headquarters'].mode()[0]
    train['Headquarters'] = train['Headquarters'].fillna(modus, inplace=True)

    print("Missing value diisi dengan modus:", modus)
# Out:
# Jumlah missing value: 0
# Presentase missing value: 0.0 %
# Jenis Missing Value :
# 480    False
# 605    False
# 61     False
# 145    False
# 353    False
# 29     False
# 163    False
# 321    False
# 215    False
# 655    False
# 405    False
# 174    False
# 431    False
# 556    False
# 449    False
# 340    False
# 606    False
# 390    False
# 209    False
# 631    False
# 601    False
# 588    False
# 549    False
# 485    False
# 434    False
# 382    False
# 104    False
# 114    False
# 603    False
# 609    False
# 470    False
# 542    False
# 7      False
# 89     False
# 507    False
# 356    False
# 493    False
# 349    False
# 341    False
# 234    False
# 140    False
# 522    False
# 43     False
# 42     False
# 73     False
# 167    False
# 227    False
# 586    False
# 66     False
# 11     False
# 593    False
# 547    False
# 530    False
# 248    False
# 335    False
# 329    False
# 274    False
# 578    False
# 177    False
# 447    False
# 412    False
# 83     False
# 421    False
# 332    False
# 617    False
# 79     False
# 23     False
# 249    False
# 357    False
# 213    False
# 260    False
# 637    False
# 296    False
# 271    False
# 137    False
# 290    False
# 33     False
# 218    False
# 247    False
# 9      False
# 22     False
# 286    False
# 591    False
# 657    False
# 646    False
# 84     False
# 314    False
# 579    False
# 490    False
# 259    False
# 203    False
# 196    False
# 294    False
# 93     False
# 277    False
# 244    False
# 451    False
# 665    False
# 28     False
# 184    False
# 541    False
# 516    False
# 178    False
# 377    False
# 153    False
# 75     False
# 381    False
# 92     False
# 375    False
# 68     False
# 585    False
# 355    False
# 534    False
# 188    False
# 15     False
# 363    False
# 265    False
# 236    False
# 231    False
# 88     False
# 567    False
# 117    False
# 494    False
# 551    False
# 238    False
# 0      False
# 664    False
# 515    False
# 660    False
# 320    False
# 116    False
# 228    False
# 291    False
# 584    False
# 525    False
# 144    False
# 527    False
# 350    False
# 607    False
# 663    False
# 268    False
# 432    False
# 46     False
# 261    False
# 195    False
# 671    False
# 612    False
# 107    False
# 429    False
# 590    False
# 304    False
# 640    False
# 328    False
# 627    False
# 312    False
# 179    False
# 327    False
# 149    False
# 124    False
# 533    False
# 581    False
# 185    False
# 398    False
# 369    False
# 662    False
# 326    False
# 620    False
# 142    False
# 141    False
# 428    False
# 19     False
# 172    False
# 545    False
# 12     False
# 305    False
# 25     False
# 486    False
# 169    False
# 445    False
# 575    False
# 245    False
# 298    False
# 404    False
# 272    False
# 154    False
# 126    False
# 499    False
# 287    False
# 113    False
# 344    False
# 173    False
# 333    False
# 57     False
# 411    False
# 222    False
# 280    False
# 17     False
# 380    False
# 322    False
# 255    False
# 388    False
# 644    False
# 190    False
# 408    False
# 592    False
# 536    False
# 94     False
# 180    False
# 301    False
# 477    False
# 422    False
# 457    False
# 399    False
# 5      False
# 45     False
# 521    False
# 559    False
# 653    False
# 16     False
# 48     False
# 650    False
# 615    False
# 3      False
# 417    False
# 426    False
# 316    False
# 283    False
# 468    False
# 285    False
# 513    False
# 225    False
# 26     False
# 529    False
# 263    False
# 50     False
# 364    False
# 229    False
# 37     False
# 157    False
# 237    False
# 645    False
# 374    False
# 370    False
# 175    False
# 568    False
# 446    False
# 194    False
# 570    False
# 396    False
# 448    False
# 649    False
# 576    False
# 67     False
# 409    False
# 168    False
# 487    False
# 162    False
# 309    False
# 193    False
# 444    False
# 365    False
# 383    False
# 462    False
# 152    False
# 577    False
# 430    False
# 226    False
# 424    False
# 539    False
# 103    False
# 537    False
# 74     False
# 115    False
# 407    False
# 648    False
# 119    False
# 501    False
# 151    False
# 403    False
# 633    False
# 207    False
# 425    False
# 453    False
# 670    False
# 519    False
# 8      False
# 574    False
# 36     False
# 139    False
# 253    False
# 303    False
# 517    False
# 634    False
# 368    False
# 59     False
# 111    False
# 526    False
# 535    False
# 647    False
# 262    False
# 622    False
# 297    False
# 414    False
# 150    False
# 433    False
# 440    False
# 266    False
# 583    False
# 359    False
# 595    False
# 38     False
# 127    False
# 423    False
# 416    False
# 307    False
# 198    False
# 351    False
# 554    False
# 146    False
# 450    False
# 623    False
# 495    False
# 419    False
# 442    False
# 597    False
# 147    False
# 528    False
# 348    False
# 463    False
# 325    False
# 506    False
# 123    False
# 569    False
# 96     False
# 143    False
# 239    False
# 394    False
# 469    False
# 488    False
# 97     False
# 371    False
# 324    False
# 279    False
# 293    False
# 254    False
# 400    False
# 122    False
# 183    False
# 202    False
# 438    False
# 323    False
# 246    False
# 415    False
# 197    False
# 543    False
# 643    False
# 171    False
# 594    False
# 503    False
# 125    False
# 402    False
# 531    False
# 523    False
# 223    False
# 550    False
# 342    False
# 53     False
# 219    False
# 129    False
# 610    False
# 514    False
# 186    False
# 613    False
# 439    False
# 511    False
# 100    False
# 518    False
# 386    False
# 651    False
# 509    False
# 267    False
# 441    False
# 496    False
# 112    False
# 232    False
# 582    False
# 373    False
# 233    False
# 532    False
# 317    False
# 410    False
# 599    False
# 358    False
# 258    False
# 282    False
# 376    False
# 384    False
# 224    False
# 638    False
# 548    False
# 472    False
# 347    False
# 505    False
# 661    False
# 621    False
# 571    False
# 85     False
# 242    False
# 159    False
# 524    False
# 35     False
# 540    False
# 170    False
# 573    False
# 608    False
# 632    False
# 95     False
# 240    False
# 460    False
# 553    False
# 587    False
# 206    False
# 392    False
# 397    False
# 636    False
# 217    False
# 4      False
# 598    False
# 546    False
# 98     False
# 406    False
# 502    False
# 47     False
# 32     False
# 200    False
# 134    False
# 27     False
# 589    False
# 230    False
# 489    False
# 378    False
# 288    False
# 418    False
# 391    False
# 498    False
# 138    False
# 62     False
# 471    False
# 128    False
# 654    False
# 520    False
# 64     False
# 14     False
# 156    False
# 40     False
# 492    False
# 379    False
# 187    False
# 216    False
# 52     False
# 337    False
# 295    False
# 251    False
# 461    False
# 455    False
# 669    False
# 269    False
# 201    False
# 161    False
# 555    False
# 401    False
# 476    False
# 105    False
# 565    False
# 389    False
# 1      False
# 628    False
# 561    False
# 80     False
# 205    False
# 34     False
# 508    False
# 427    False
# 454    False
# 366    False
# 91     False
# 339    False
# 564    False
# 345    False
# 241    False
# 13     False
# 315    False
# 600    False
# 387    False
# 273    False
# 166    False
# 666    False
# 484    False
# 656    False
# 504    False
# 243    False
# 566    False
# 562    False
# 189    False
# 475    False
# 510    False
# 58     False
# 474    False
# 560    False
# 252    False
# 21     False
# 313    False
# 459    False
# 160    False
# 276    False
# 191    False
# 385    False
# 413    False
# 491    False
# 343    False
# 308    False
# 130    False
# 99     False
# 372    False
# 87     False
# 458    False
# 330    False
# 214    False
# 466    False
# 121    False
# 614    False
# 20     False
# 71     False
# 106    False
# 270    False
# 435    False
# 102    False
# Name: Headquarters, dtype: bool
# Kolom tidak di-drop karena missing value <= 20%
# Missing value diisi dengan modus: New York, NY
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_30756\1735178126.py:22: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   train['Headquarters'] = train['Headquarters'].fillna(modus, inplace=True)

# %% [markdown]
# # D. Encoding
# Definisi : Mengubah tipe kategorikal menjadi numerikal dengan pendekatan aturan encoding untuk persiapan sebelum dilakukannya machine learning modelling. Teknik Encoding yang umum dipakai :
# 1. One Hot Encoding (OHE) : Lakukan pada kolom gender
# 2. Label Encoding / Ordinal Encoding : Lakukan pada kolom Yes dan No, Jika Yes menjadi 1 , Jika No menjadi 0. Sebagai Contohnya di kolom  Partner, Dependents.
# 3. Mean Encoding : Contract

# %%
df_churn = pd.read_csv('TelcoCustomerChurn.csv')

# %%
#Splitting terlebih dahulu
from sklearn.model_selection import train_test_split

train, test = train_test_split(df_churn, test_size=0.2, random_state=42)

print("Jumlah data train:", len(train))
print("Jumlah data test:", len(test))
# Out:
# Jumlah data train: 5634
# Jumlah data test: 1409

# %% [markdown]
# ## Assignment 3.a Label Encoder :
# 1. Pilih kolom-kolom StreamingMovies, StreamingTV, TechSupport, DeviceProtection, OnlineBackup, OnlineSecurity, MultipleLines
# 2. Ganti nilai yang tidak sesuai : No internet service menjadi No lalu validasi dengan value_counts
# 3. Kemudian lakukan label Encoder
# 4. Notes : gunakan Telco-Customer-Churn.csv

# %%
#Tulis jawaban
from sklearn.preprocessing import LabelEncoder

# %%
kolom = ['StreamingMovies','StreamingTV','TechSupport',
        'DeviceProtection','OnlineBackup','OnlineSecurity',
        'MultipleLines']

train[kolom].head(10)
# Out:
#      StreamingMovies StreamingTV TechSupport DeviceProtection OnlineBackup  \
# 2142             Yes          No          No              Yes           No
# 1623             Yes         Yes          No               No          Yes
# 6074              No          No          No               No           No
# 1362              No          No          No               No           No
# 6754              No          No         Yes               No          Yes
# 1212              No          No          No               No           No
# 2722              No          No          No               No           No
# 4006              No          No          No               No           No
# 6791              No         Yes          No              Yes           No
# 5466              No          No          No               No           No
#
#      OnlineSecurity     MultipleLines
# 2142            Yes                No
# 1623             No               Yes
# 6074             No  No phone service
# 1362             No                No
# 6754            Yes               Yes
# 1212             No                No
# 2722             No                No
# 4006             No                No
# 6791             No  No phone service
# 5466             No                No

# %%
kolom = ['StreamingMovies','StreamingTV','TechSupport',
         'DeviceProtection','OnlineBackup','OnlineSecurity',
         'MultipleLines']
for k in kolom:
    train[k] = train[k].replace({'No internet service': 'No'})

for k in kolom:
    print(k)
    print(train[k].value_counts())
    print()
# Out:
# StreamingMovies
# StreamingMovies
# No     3437
# Yes    2197
# Name: count, dtype: int64
#
# StreamingTV
# StreamingTV
# No     3453
# Yes    2181
# Name: count, dtype: int64
#
# TechSupport
# TechSupport
# No     4005
# Yes    1629
# Name: count, dtype: int64
#
# DeviceProtection
# DeviceProtection
# No     3703
# Yes    1931
# Name: count, dtype: int64
#
# OnlineBackup
# OnlineBackup
# No     3662
# Yes    1972
# Name: count, dtype: int64
#
# OnlineSecurity
# OnlineSecurity
# No     4024
# Yes    1610
# Name: count, dtype: int64
#
# MultipleLines
# MultipleLines
# No                  2685
# Yes                 2397
# No phone service     552
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for k in kolom:
    train[k] = le.fit_transform(train[k])

train[kolom].head(10)
# Out:
#       StreamingMovies  StreamingTV  TechSupport  DeviceProtection  \
# 2142                1            0            0                 1
# 1623                1            1            0                 0
# 6074                0            0            0                 0
# 1362                0            0            0                 0
# 6754                0            0            1                 0
# 1212                0            0            0                 0
# 2722                0            0            0                 0
# 4006                0            0            0                 0
# 6791                0            1            0                 1
# 5466                0            0            0                 0
#
#       OnlineBackup  OnlineSecurity  MultipleLines
# 2142             0               1              0
# 1623             1               0              2
# 6074             0               0              1
# 1362             0               0              0
# 6754             1               1              2
# 1212             0               0              0
# 2722             0               0              0
# 4006             0               0              0
# 6791             0               0              1
# 5466             0               0              0

# %% [markdown]
# ## Selesai :)
